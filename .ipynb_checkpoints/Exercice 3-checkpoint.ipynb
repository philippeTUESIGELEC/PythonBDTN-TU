# %% [markdown]
# #Analyse reproductible en Python Exercice 3 - Séance 1
# Author : Philippe Tu BDTN - Promotion 2019
# Creation Date: 11 / 03 / 2018
# Steps in this notebook :
# 1. Load txt file & Data cleaning
# 2. Calculating words occurences
# 3. Display & analysis of the distribution

# %% [markdown]
# Step 1 : Load file & Data Cleaning
# Let's start by opening the text file. The initial file has a lot of empty lines, so we use error_bad_lines=False
# The initial txt file also has special characters, we'll open it with utf-8 encoding.

# %%
# %%capture
import pandas as pd
data = pd.read_csv('lesmiserables01hugogoog_djvu.txt',header=None,error_bad_lines=False,encoding ='utf-8') 
data.columns=["ligne"];

# %% [markdown]
# Let's take a look at the first and last lines

# %%
data
# Out:
#                                                   ligne
# 0                                               Google
# 1     This is a digital copy of a book thaï was prcs...
# 2       to make the world's bocks discoverablc online.
# 3     It has survived long enough for the copyright ...
# 4     to copyright or whose légal copyright term has...
# 5           publisher to a library and finally to you.
# 6                                     Usage guidelines
# 7     Google is proud to partner with libraries to d...
# 8                                We also ask that you:
# 9     + Refrain fivm automated querying Do nol send ...
# 10    use of public domain materials for thèse purpo...
# 11    + Maintain attributionTht GoogX'S "watermark" ...
# 12    additional materials through Google Book Searc...
# 13    any spécifie book is allowed. Please do not as...
# 14    anywhere in the world. Copyright infringement ...
# 15                            About Google Book Search
# 16    Google's mission is to organize the world's in...
# 17    discover the world's books while helping autho...
# 18                    at |http: //books. google .com/l
# 19                                                Cd?.
# 20                                                 le.
# 21                                                 LES
# 22                                          MISÉRABLES
# 23                                       TOME DEUXIÈME
# 24                                            EDITEURS
# 25                                                  le
# 26                                         A BRUXELIES
# 27                                         VICTOR HUGO
# 28                                                  •V
# 29                                                 LES
# ...                                                 ...
# 3816                                    LIVRE SEPTIÈME
# 3817                            l'affaire champmatuieu
# 3818                           I. La sœur Simplice 469
# 3819  II. Perspicacité de maître Scaufflaire. . . '....
# 3820            III. Une tempête sous un crâne • . 487
# 3821  IV. Formes que prend la souffrance pendant le ...
# 3822                                           meil no
# 3823                     V. Bâtons dans les roues S133
# 3824          \i. La sœur Simplice mise à répreuve 257
# 3825  VII. Le voyageur arrivé prend ses précautions ...
# 3826                         repartir. . . ' T . . 274
# 3827                        VIII. Entrée de faveur 281
# 3828  IX. Un lieu où des convictions sont en train d...
# 3829                                        former 289
# 3830                  X. Le système de dénégations 303
# 3831  xi. Champmathieu de plus en plus étonné» . • •...
# 3832                                    LIVRE HUITIÈME
# 3833                                       CONTRE-COUP
# 3834  I. Dans quel miroir M. Madeleine regarde ses c...
# 3835                                          veux 331
# 3836                          II. Fanline heureuse 3T7
# 3837                                        889 TABLB.
# 3838                          III. ja vert content 347
# 3839         I V. L'autorité reprend ses droits. • 355
# 3840                  V. Tombeau convenable. . .X* 305
# 3841                                          75760473
# 3842                                          a TABLS.
# 3843                         i:i- J»-.eît ccifriL 3>*T
# 3844               T. Tccil']aa oCfLveoabie. ...v i-^S
# 3845                                          75760473
#
# [3846 rows x 1 columns]

# %% [markdown]
# It looks like 21 lines aren't useful for the analysis. Let's take out those lines

# %%
data.drop(data.index[:21],inplace=True)
data = data.reset_index(drop=True)
data
# Out:
#                                                   ligne
# 0                                                  LES
# 1                                           MISÉRABLES
# 2                                        TOME DEUXIÈME
# 3                                             EDITEURS
# 4                                                   le
# 5                                          A BRUXELIES
# 6                                          VICTOR HUGO
# 7                                                   •V
# 8                                                  LES
# 9                                           MISÉRABLES
# 10                                     PREMIÈRE PARTIE
# 11                                             FANTINE
# 12                                                  II
# 13                                               PARIS
# 14                                         BRU XELL ES
# 15                                        M DCCC LXIII
# 16    Tous droits de reproduction et de traduction r...
# 17                                     LIVRE QUATRIÈME
# 18                                               !.. ^
# 19                 UNE HÈRE QUI EN RENCONTRE UNE AUTRE
# 20    qui n'existe plus aujourd'hui. Cette gargote é...
# 21    femme. Elle était située dans la ruelle du Bou...
# 22    ger. On voyait au-dessus de la porte une planche
# 23    clouée à plat sur le mur. Sur cette planche ét...
# 24      peint quelque chose qui ressemblait à un homme
# 25                                   4 LES MISÉRABLES.
# 26     de grosses épaulettes de général dorées avec de
# 27    larges étoiles argentées; des taches rouges fi...
# 28    raient du sang ; le reste du tableau était de la
# 29    fumée et représentait probablement une bataille.
# ...                                                 ...
# 3795                                    LIVRE SEPTIÈME
# 3796                            l'affaire champmatuieu
# 3797                           I. La sœur Simplice 469
# 3798  II. Perspicacité de maître Scaufflaire. . . '....
# 3799            III. Une tempête sous un crâne • . 487
# 3800  IV. Formes que prend la souffrance pendant le ...
# 3801                                           meil no
# 3802                     V. Bâtons dans les roues S133
# 3803          \i. La sœur Simplice mise à répreuve 257
# 3804  VII. Le voyageur arrivé prend ses précautions ...
# 3805                         repartir. . . ' T . . 274
# 3806                        VIII. Entrée de faveur 281
# 3807  IX. Un lieu où des convictions sont en train d...
# 3808                                        former 289
# 3809                  X. Le système de dénégations 303
# 3810  xi. Champmathieu de plus en plus étonné» . • •...
# 3811                                    LIVRE HUITIÈME
# 3812                                       CONTRE-COUP
# 3813  I. Dans quel miroir M. Madeleine regarde ses c...
# 3814                                          veux 331
# 3815                          II. Fanline heureuse 3T7
# 3816                                        889 TABLB.
# 3817                          III. ja vert content 347
# 3818         I V. L'autorité reprend ses droits. • 355
# 3819                  V. Tombeau convenable. . .X* 305
# 3820                                          75760473
# 3821                                          a TABLS.
# 3822                         i:i- J»-.eît ccifriL 3>*T
# 3823               T. Tccil']aa oCfLveoabie. ...v i-^S
# 3824                                          75760473
#
# [3825 rows x 1 columns]

# %% [markdown]
# Row 3761 to last line aren't in the book, lets take them out too.

# %%
data.tail(70)
# Out:
#                                                   ligne
# 3755                               370 LES MISBKABLBS.
# 3756  perd les pauvres. Heureusement Dieu sait oii re-
# 3757  trouver rame. On coucha Fantine dans les ténèb...
# 3758  parmi les premiers os venus ; elle subit la pr...
# 3759  des cendres. Elle fut jetée à la fosse publiqu...
# 3760                        tombe ressembla à son lit.
# 3761                              FIN DD TOMB DEUXIEME
# 3762                        ET 1)£ LA PBFtflkBE PABTIB
# 3763                                             TABLE
# 3764                                             TABLE
# 3765                                  DU TOME DEUXIÈME
# 3766                                   PREMIÈRE PARTIE
# 3767                                           FANTINE
# 3768                                   LIVRE QUATRIÈME
# 3769    I. Une mère qui en rencontre une autre. ...» 3
# 3770  II. Première esquisse de deux figures louches....
# 3771                               II :. L'Alouette 27
# 3772                                        380 TABLB.
# 3773                                   LIVRE CINQUIÈME
# 3774                                       LA DESCENTE
# 3775  I. Histoire d'un progrès dans les verroleries ...
# 3776                              II. M Madeleine ' 39
# 3777             III. Sommes déposées chez LafiBtte 47
# 3778              IV. M. Madeleine en deuil • • . . 55
# 3779                  \. Vagues éclairs à l'horizon 64
# 3780                       VI. Le père Fauchelevent 73
# 3781  \ii. Fauchelevent devient jardinier à Paris. ....
# 3782  VIII. Madame Victumien dépense trente francs p...
# 3783                                         morale 85
# 3784        IX. Succès de madame Victurnien. ..••.• 91
# ...                                                 ...
# 3795                                    LIVRE SEPTIÈME
# 3796                            l'affaire champmatuieu
# 3797                           I. La sœur Simplice 469
# 3798  II. Perspicacité de maître Scaufflaire. . . '....
# 3799            III. Une tempête sous un crâne • . 487
# 3800  IV. Formes que prend la souffrance pendant le ...
# 3801                                           meil no
# 3802                     V. Bâtons dans les roues S133
# 3803          \i. La sœur Simplice mise à répreuve 257
# 3804  VII. Le voyageur arrivé prend ses précautions ...
# 3805                         repartir. . . ' T . . 274
# 3806                        VIII. Entrée de faveur 281
# 3807  IX. Un lieu où des convictions sont en train d...
# 3808                                        former 289
# 3809                  X. Le système de dénégations 303
# 3810  xi. Champmathieu de plus en plus étonné» . • •...
# 3811                                    LIVRE HUITIÈME
# 3812                                       CONTRE-COUP
# 3813  I. Dans quel miroir M. Madeleine regarde ses c...
# 3814                                          veux 331
# 3815                          II. Fanline heureuse 3T7
# 3816                                        889 TABLB.
# 3817                          III. ja vert content 347
# 3818         I V. L'autorité reprend ses droits. • 355
# 3819                  V. Tombeau convenable. . .X* 305
# 3820                                          75760473
# 3821                                          a TABLS.
# 3822                         i:i- J»-.eît ccifriL 3>*T
# 3823               T. Tccil']aa oCfLveoabie. ...v i-^S
# 3824                                          75760473
#
# [70 rows x 1 columns]

# %% [markdown]
# We have to delete the last 64 lines of the dataframe

# %%
data.drop(data.tail(64).index,inplace=True)
data = data.reset_index(drop=True)
data.tail(30)
# Out:
#                                                   ligne
# 3731                         La sœur répondit : — Non.
# 3732                                           dévoue.
# 3733                                     profondément.
# 3734    sainte fille! vous n'êtes plus de ce monde de-
# 3735  puis beaucoup d'années; vous avez rejoint dans...
# 3736   lumière vos sœurs les vierges et vos frères les
# 3737  anges ; que ce mensonge vous soit compté dans le
# 3738                                         paradis !
# 3739  L'affirmation de la sœur fut pour Javert quelque
# 3740  chose de si décisif qu'il ne remarqua même pas...
# 3741                         TOMBRAU CONVENABLE. 37rj.
# 3742  singularité de cette bougie qu'on venait de so...
# 3743                       et qui fumait sur la table.
# 3744  de M.^ — sur M. — dans la direction de Paris. ...
# 3745  témoignage de deux ou trois rouliers qui l'ava...
# 3746  vêtu d'une blouse. Où avait-il pris cette blou...
# 3747  était mort quelques jours auparavant à l'infir...
# 3748                               peut-être celle-là.
# 3749                       Un dernier mot sur Fantine.
# 3750                             Fantine à cette mère.
# 3751  de quoi s'agissait-il? d'un forçat et d'une fi...
# 3752  publique. C'est pourquoi il simplifia l'enterr...
# 3753                   qu'on appelle la fosse commune.
# 3754  Fantine fut donc enterrée dans le coin gratis du
# 3755                               370 LES MISBKABLBS.
# 3756  perd les pauvres. Heureusement Dieu sait oii re-
# 3757  trouver rame. On coucha Fantine dans les ténèb...
# 3758  parmi les premiers os venus ; elle subit la pr...
# 3759  des cendres. Elle fut jetée à la fosse publiqu...
# 3760                        tombe ressembla à son lit.

# %% [markdown]
# 2. Calculating words occurences
# Lets concatenate every row into a single string first, then count the frequency of each word.

# %%
import re
stringWholeText=''.join(data.ligne)
stringWholeText=stringWholeText.replace("- ","") #Removing bonds in the text
stringWholeText = re.sub(r'[^\w\s]','',stringWholeText) #Removing punctuation using regex
print(stringWholeText[0:200])
# Out:
# LES MISÉRABLES TOME DEUXIÈME EDITEURS le A BRUXELIES VICTOR HUGO V LES MISÉRABLES PREMIÈRE PARTIE FANTINE II PARIS BRU XELL ES M DCCC LXIII Tous droits de reproduction et de traduction rùservés LIVRE

# %% [markdown]
# Now we have a single string that contains the whole "Les misérables" text

# %%
import string #Regex library
from collections import Counter
wordlist = stringWholeText.split() # We put the different words in a list using split function
wordFrequency=[]
for word in wordlist: #Counting and putting the result for each word existing in the text in a list called wordFrequency
    wordFrequency.append(wordlist.count(word))

# %%
#Now lets put the words and their frequencies into a single dictionary
wordsAndFrequencies = dict(zip(wordlist,wordFrequency))
wordsAndFrequencies
sample={k: wordsAndFrequencies[k] for k in list(wordsAndFrequencies)[:20]}
sample
# Out:
# {'A': 47,
#  'BRU': 1,
#  'BRUXELIES': 1,
#  'DEUXIÈME': 1,
#  'EDITEURS': 1,
#  'ES': 1,
#  'FANTINE': 4,
#  'HUGO': 1,
#  'II': 30,
#  'LES': 98,
#  'M': 202,
#  'MISÉRABLES': 77,
#  'PARIS': 3,
#  'PARTIE': 1,
#  'PREMIÈRE': 4,
#  'TOME': 1,
#  'V': 3,
#  'VICTOR': 1,
#  'XELL': 1,
#  'le': 658}

# %% [markdown]
# We also have to get rid of numbers in keys and their frequency, it can pollute our final plots.

# %%
def hasNumbers(string): #This function returns True if a string contains a digit.
    return any(index.isdigit() for index in string)
# Now we delete the key;value couples that has digits as a key.
wordsAndFrequencies={k: v 
                     for k, v in wordsAndFrequencies.items() 
                         if hasNumbers(k) is False}

# %%
#Now let's put the result into a dataframe and plot it
#dataFrameResult=pd.Series(wordsAndFrequencies, name='Words Frenquencies')
dataFrameResult = pd.Series(wordsAndFrequencies, name='frequency') 
dataFrameResult.reset_index()
# Out:
#                 index  frequency
# 0                   A         47
# 1               ABLBS          1
# 2              ARRIVÉ          3
# 3               AUTRB          1
# 4               AUTRE          7
# 5               AUTRa          1
# 6            Accablée          1
# 7         Accordezmoi          1
# 8         AflSBRABLBS          1
# 9                  Ah         16
# 10                 Ai          1
# 11               Aije          1
# 12              Ainsi          3
# 13              Albin          1
# 14             Alfred          1
# 15          Alighieri          1
# 16          Allezvous          1
# 17             Allons          1
# 18              Alors         10
# 19           Alouette          1
# 20           Alphonse          1
# 21         Amusezvous          1
# 22            Antoine          1
# 23         Appellemoi          1
# 24              Après         11
# 25              Arras         22
# 26             Arrivé          2
# 27             Arthur          1
# 28               Astu          2
# 29               Atcm          1
# ...               ...        ...
# 7404         étroites          1
# 7405          étroits          1
# 7406           étudié          1
# 7407            étymo          1
# 7408              été         51
# 7409     étîncelèrent          1
# 7410          évanoui          1
# 7411         évanouir          1
# 7412  évanouissements          2
# 7413          éveillé          1
# 7414      éventualité          1
# 7415       évidemment          5
# 7416          évident          8
# 7417           éviter          1
# 7418           évitât          1
# 7419              évé          1
# 7420        événement          3
# 7421       événements          2
# 7422           évêque          1
# 7423                ê          1
# 7424             êtes         11
# 7425         êtesvous          1
# 7426             être         44
# 7427            êtres          5
# 7428                î          1
# 7429               îl          2
# 7430               ît          1
# 7431              ôta          1
# 7432         ôtesvous          1
# 7433              œil          3
#
# [7434 rows x 2 columns]

# %%
# The dataframe has no words with digits, looks good, now let's plot.
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plot = sns.kdeplot(dataFrameResult)
plot.set(xlabel='Frequency of words in text',ylabel="Mathematical Frequency")
plt.show()

# %% [markdown]
# Analysis : A lot of words has a little frequencies in the text (between 1 and 150-170), they are likely to be complicated words, words that are not often used in oral. Words that has a frequency between 200-400 would be verbs.
# Finally, there are words that are found more than 500 times (600+ times, 800, 800, 1300, 1400). They are likely to be pronouns, subjects, articles.
# This survey confirms the richness of French as a lot of words has some correct frenquency in "Les Misérables" (around 100-200). We would likely find more words around 200-500 times on a text in English.
